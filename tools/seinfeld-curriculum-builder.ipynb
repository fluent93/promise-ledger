# %% [markdown]
# # Seinfeld full-series curriculum builder
#
# Drive에 있는 원본 영상과 자막을 복사하지 않고 읽어 시즌 순서의 회차 카탈로그와 회당 5개의 학습 후보를 만듭니다. 후보는 앱에 바로 공개되지 않으며 화자와 번역을 검수한 뒤 승격합니다.

# %%
# !pip -q install pysubs2
from google.colab import drive
drive.mount('/content/drive')

# %%
# %run "/content/drive/MyDrive/Seinfeld English Clips/seinfeld-curriculum-builder.py"
